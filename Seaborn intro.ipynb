# %%
from matplotlib import pyplot as plt

# %%
x = [5,10,15,20]
y = [2,1,6,3]
plt.xlabel('time')
plt.ylabel('velocity')
plt.title('Velocity time graph')
plt.plot(x,y, color='green', marker='o', linestyle="dotted", linewidth=2, markersize = 12);

# %% [markdown]
# # styles(Matplotlib)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
x = [5,10,15,20]
y = [2,1,6,3]
plt.xlabel('time')
plt.ylabel('velocity')
plt.title('Velocity time graph')
plt.plot(x,y);

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark')
plt.plot(x,y);

# %%
matplotlib.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-dd805d611f8f> in <module>
# ----> 1 matplotlib.__version__
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
cars = sns.load_dataset('penguins')

# %%
cars.shape
# Out:
# (344, 7)

# %%
cars.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
cars.dropna(inplace=True) # dropping the rows which contains certain missing entries if axis = 0 else drop column if axis = 1. 
                          #Inplace= true updates the datset after dropping
cars.shape  # Returns the number of rows and columns
# Out:
# (333, 7)

# %%
x = cars.()
